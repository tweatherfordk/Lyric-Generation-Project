# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras.utils import to_categorical

# %%
import numpy
import sys
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

# %%
corpus_df = pd.read_csv("/Users/weatherford/Documents/Flatiron/Lyric-Generation-Project/lyric_corpus.csv")
corpus_df.drop(columns = 'Unnamed: 0', inplace = True)
corpus_df
# Out:
#           Artist               Song Title  \
# 0       Lifetime           Turnpike Gates
# 1       Lifetime  Young, Loud, and Scotty
# 2       Lifetime         25 Cent Giraffes
# 3       Lifetime              Hey Catrine
# 4       Lifetime              Rodeo Clown
# ...          ...                      ...
# 1249  Gerard Way   Morning Pages: 9/30/16
# 1250  Gerard Way  Morning Pages: 10/03/16
# 1251  Gerard Way  Morning Pages: 10/14/16
# 1252  Gerard Way  Morning Pages: 10/04/16
# 1253  Gerard Way   Fireworks for The Dead
#
#                                                  Lyrics
# 0     Turnpike Gates Lyrics[Spoken]\nIn order for yo...
# 1     Young, Loud, and Scotty LyricsIs it silly to t...
# 2     25 Cent Giraffes LyricsIt was too loud to hear...
# 3     Hey Catrine LyricsHey Catrine, I know it's tru...
# 4     Rodeo Clown Lyrics[Verse 1]\nReturn it to you,...
# ...                                                 ...
# 1249  Morning Pages: 9/30/16 LyricsHad a great day o...
# ...

# %%
type(corpus_df.Lyrics[10])
# Out:
# str

# %%
lyrics_df = corpus_df['Lyrics']
lyrics_df
# Out:
# 0       Turnpike Gates Lyrics[Spoken]\nIn order for yo...
# 1       Young, Loud, and Scotty LyricsIs it silly to t...
# 2       25 Cent Giraffes LyricsIt was too loud to hear...
# 3       Hey Catrine LyricsHey Catrine, I know it's tru...
# 4       Rodeo Clown Lyrics[Verse 1]\nReturn it to you,...
#                               ...
# 1249    Morning Pages: 9/30/16 LyricsHad a great day o...
# 1250    Morning Pages: 10/03/16 LyricsI love Monday mo...
# 1251    Morning Pages: 10/14/16 LyricsYesterday starte...
# 1252    Morning Pages: 10/04/16 LyricsMuch to do. Prep...
# 1253    Fireworks for The Dead LyricsFireworks for the...
# Name: Lyrics, Length: 1254, dtype: object

# %%
lyrics_list = list(lyrics_df)
type(lyrics_list)
# Out:
# list

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
#words=word_tokenize(lyrics_df)

words = [word_tokenize(doc) for doc in str(corpus_df['Lyrics'])]
words=" ".join(words)
words[0:25]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-6574ec4d3dfc> in <module>
#       3
#       4 words = [word_tokenize(doc) for doc in str(corpus_df['Lyrics'])]
# ----> 5 words=" ".join(words)
#       6 words[0:25]
#
# TypeError: sequence item 0: expected str instance, list found

# %%
chars =(list(set(lyrics_df)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
# Out:
# {nan: 0,
# ...
