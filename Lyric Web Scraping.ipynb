# %% [markdown]
# # Lyric Web Scraping

# %%
# !pip install git+https://github.com/johnwmillr/LyricsGenius.git
# Out:
# ...
#   Cloning https://github.com/johnwmillr/LyricsGenius.git to /private/var/folders/2p/pcvv1y9n2dv93ljvsssdw2_h0000gn/T/pip-req-build-x0m316v3
# ...
#   Created wheel for lyricsgenius: filename=lyricsgenius-3.0.1-py3-none-any.whl size=44669 sha256=fe352597c032d129fe5afce169570c6c94131818c3afe1d074d6067bb32a0836
#   Stored in directory: /private/var/folders/2p/pcvv1y9n2dv93ljvsssdw2_h0000gn/T/pip-ephem-wheel-cache-akhsz6o_/wheels/64/c0/2c/8e83de1c83814299822723e7471f38a2dfbd750de606c7ccbd
# Successfully built lyricsgenius
# ...

# %%
import apikey
import pandas as pd

# %%
client_access_token = apikey.load("Genius")

# %%
import lyricsgenius
genius = lyricsgenius.Genius(client_access_token)

# %% [markdown]
# ### Genius Test

# %%
artist = genius.search_artist("The Cure", max_songs = 10, sort = "title")
print(artist.songs)
# Out:
# Searching for songs by The Cure...
#
# Song 1: "10:15 Saturday Night"
# Song 2: "10:15 Saturday Night (Chestnut Studio Demo 05/78)"
# Song 3: "10:15 Saturday Night (Live In Nottingham 10/79)"
# Song 4: "10:15 Saturday Night - New Version / Live Version (1984)"
# Song 5: "10:15 Saturday Night (Robert Smith Home Demo 02/78)"
# Song 6: "2 Late"
# "2 Late (Alternative Version) - Band Instrumental Demo" is not valid. Skipping.
# Song 7: "2 Late (Studio ‘WIP’ Mix 11/88)"
# Song 8: "39"
# Song 9: "39 - Live (Curaetion)"
# Song 10: "50 Ways To Say Goodbye"
#
# Reached user-specified song limit (10).
# Done. Found 10 songs.
# [Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...)]

# %% [markdown]
# # Song Lyrics

# %% [markdown]
# - Extract song lyrics by artist

# %% [markdown]
# ## Lifetime

# %%
# Get unique artist ID
artist1 = genius.search_artists("Lifetime")
print(artist1['sections'][0]['hits'][0]['result']['id'])
# Out:
# 357047

# %%
lifetime = genius.search_artist("Lifetime", artist_id = 357047)
for song in lifetime.songs:
    print(song.lyrics)
# Out:
# Song 1: "Turnpike Gates"
# Song 2: "Young, Loud, and Scotty"
# Song 3: "25 Cent Giraffes"
# Song 4: "Hey Catrine"
# Song 5: "Rodeo Clown"
# Song 6: "Theme Song for a New Brunswick Basement Show"
# Song 7: "Daneurysm"
# Song 8: "Haircuts & T-Shirts"
# Song 9: "Francie Nolan"
# Song 10: "The Boy’s No Good"
# Song 11: "Northbound Breakdown"
# Song 12: "Cut the Tension"
# Song 13: "(The Gym Is) Neutral Territory"
# Song 14: "Anchor"
# Song 15: "All Night Long"
# Song 16: "Ostrichsized"
# Song 17: "Bringin’ It Backwards"
# Song 18: "Irony Is for Suckers"
# Song 19: "Knives Bats New Tats"
# Song 20: "Just A Quiet Evening"
# Song 21: "Somewhere In the Swamps of Jersey"
# Song 22: "I Like You OK"
# Song 23: "How We Are"
# Song 24: "Airport Monday Morning"
# Song 25: "Bobby Truck Tricks"
# Song 26: "The Truth About Lars"
# Song 27: "I’m Not Calling You"
# Song 28: "What She Said"
# Song 29: "Can’t Think About It Now"
# Song 30: "The Verona Kings"
# Song 31: "It’s Not Funny Anymore"
# ...

# %%
lifetime = artist2

# %% [markdown]
# ## The Cure

# %%
artist2 = genius.search_artists("The Cure")
print(artist2['sections'][0]['hits'][0]['result']['id'])
# Out:
# 15758

# %%
cure = genius.search_artist("The Cure", artist_id = 15758)
for song in cure.songs:
    print(song.lyrics)
# Out:
# Song 1: "Lovesong"
# Song 2: "Just Like Heaven"
# Song 3: "Friday I’m in Love"
# Song 4: "Boys Don’t Cry"
# Song 5: "Pictures of You"
# Song 6: "Lullaby"
# Song 7: "Close to Me"
# Song 8: "Disintegration"
# Song 9: "In Between Days"
# Song 10: "A Forest"
# Song 11: "A Letter to Elise"
# Song 12: "Plainsong"
# Song 13: "Fascination Street"
# Song 14: "The Lovecats"
# Song 15: "One Hundred Years"
# Song 16: "Pornography"
# Song 17: "Killing an Arab"
# Song 18: "The Same Deep Water as You"
# Song 19: "Burn"
# Song 20: "Closedown"
# Song 21: "Untitled"
# Song 22: "Last Dance"
# Song 23: "The Figurehead"
# Song 24: "A Night Like This"
# Song 25: "Siamese Twins"
# Song 26: "Why Can’t I Be You?"
# Song 27: "Let’s Go to Bed"
# Song 28: "Prayers for Rain"
# Song 29: "M"
# Song 30: "Cold"
# Song 31: "10:15 Saturday Night"
# Song 32: "Homesick"
# Song 33: "How Beautiful You Are"
# Song 34: "From the Edge of the Deep Green Sea"
# Song 35: "Jumping Someone Else’s Train"
# Song 36: "Faith"
# ...

# %%
print(cure.songs[3])
# Out:
# "Boys Don’t Cry" by The Cure:
#     Boys Don’t Cry Lyrics[Verse 1]
#     I would say I'm sorry
#     If I thought that it would change your mind
#     But...

# %% [markdown]
# ## Jawbreaker

# %%
artist3 = genius.search_artists("Jawbreaker")
print(artist3['sections'][0]['hits'][0]['result']['id'])
# Out:
# 246883

# %%
jawbreaker = genius.search_artist("Jawbreaker", artist_id = 246883)
for song in jawbreaker.songs:
    print(song.lyrics)
# Out:
# Song 1: "Accident Prone"
# Song 2: "Boxcar"
# Song 3: "Kiss the Bottle"
# Song 4: "Sluttering (May 4th)"
# Song 5: "The Boat Dreams from the Hill"
# Song 6: "Do You Still Hate Me?"
# Song 7: "Chesterfield King"
# Song 8: "Want"
# Song 9: "Million"
# Song 10: "Jinx Removing"
# Song 11: "Save Your Generation"
# Song 12: "Jet Black"
# Song 13: "Condition Oakland"
# Song 14: "I Love You So Much It’s Killing Us Both"
# Song 15: "Fireman"
# Song 16: "Ache"
# Song 17: "Unlisted Track"
# Song 18: "Shield Your Eyes"
# Song 19: "Chemistry"
# Song 20: "Sea Foam Green"
# Song 21: "Bad Scene, Everyone’s Fault"
# Song 22: "Indictment"
# Song 23: "Oyster"
# Song 24: "Ashtray Monument"
# Song 25: "In Sadding Around"
# Song 26: "West Bay Invitational"
# Song 27: "Bivouac"
# Song 28: "Lurker II: Dark Son of Night"
# Song 29: "Outpatient"
# Song 30: "Busy"
# Song 31: "Basilica"
# Song 32: "Donatello"
# Song 33: "Tour Song"
# Song 34: "Imaginary War"
# Song 35: "Shirt"
# Song 36: "Seethruskin"
# ...

# %% [markdown]
# ## My Chemical Romance

# %%
artist4 = genius.search_artists("My Chemical Romance")
print(artist4['sections'][0]['hits'][0]['result']['id'])
# Out:
# 18261

# %%
mcr = genius.search_artist("My Chemical Romance", artist_id = 18261)
for song in mcr.songs:
    print(song.lyrics)
# Out:
# Song 1: "Welcome to the Black Parade"
# Song 2: "Helena (So Long & Goodnight)"
# Song 3: "Teenagers"
# Song 4: "I’m Not Okay (I Promise)"
# Song 5: "The Foundations of Decay"
# Song 6: "Mama"
# Song 7: "I Don’t Love You"
# Song 8: "Famous Last Words"
# Song 9: "The Ghost of You"
# Song 10: "Cancer"
# Song 11: "Na Na Na (Na Na Na Na Na Na Na Na Na)"
# Song 12: "You Know What They Do to Guys Like Us in Prison"
# Song 13: "Dead!"
# Song 14: "The Sharpest Lives"
# Song 15: "Disenchanted"
# Song 16: "This Is How I Disappear"
# Song 17: "Thank You for the Venom"
# Song 18: "The End."
# Song 19: "House of Wolves"
# Song 20: "It’s Not a Fashion Statement, It’s a Fucking Deathwish"
# Song 21: "Sleep"
# Song 22: "Demolition Lovers"
# Song 23: "Cemetery Drive"
# Song 24: "Give ’Em Hell, Kid"
# Song 25: "I Never Told You What I Do for a Living"
# Song 26: "The Jetset Life Is Gonna Kill You"
# Song 27: "To the End"
# Song 28: "Blood"
# ...

# %% [markdown]
# ## Blink-182

# %%
artist5 = genius.search_artists("blink-182")
print(artist5['sections'][0]['hits'][0]['result']['id'])
# Out:
# 13373

# %%
blink = genius.search_artist("blink-182", artist_id = 13373)
for song in blink.songs:
    print(song.lyrics)
# Out:
# Changing artist name to '​​blink-182'
# Song 1: "I Miss You"
# Song 2: "All the Small Things"
# Song 3: "What’s My Age Again?"
# Song 4: "Adam’s Song"
# Song 5: "Feeling This"
# Song 6: "Dammit"
# Song 7: "First Date"
# Song 8: "She’s Out of Her Mind"
# Song 9: "Bored To Death"
# Song 10: "EDGING"
# Song 11: "Stay Together for the Kids"
# Song 12: "Always"
# Song 13: "Dumpweed"
# Song 14: "I Really Wish I Hated You"
# Song 15: "Fuck a Dog"
# Song 16: "Dysentery Gary"
# Song 17: "Misery"
# Song 18: "The Rock Show"
# Song 19: "All of This"
# Song 20: "Josie"
# Song 21: "Aliens Exist"
# Song 22: "Stockholm Syndrome"
# Song 23: "Going Away to College"
# Song 24: "The Party Song"
# Song 25: "Brohemian Rhapsody"
# Song 26: "Blame It on My Youth"
# Song 27: "Down"
# Song 28: "Mutt"
# Song 29: "Cynical"
# Song 30: "Anthem"
# Song 31: "Home Is Such a Lonely Place"
# Song 32: "California"
# Song 33: "Online Songs"
# Song 34: "Sober"
# Song 35: "San Diego"
# Song 36: "I’m Lost Without You"
# ...

# %%
print(blink.songs[4].lyrics)
# Out:
# Feeling This Lyrics[Intro]
# Get ready for action!
#
# [Verse 1: Tom DeLonge & (Mark Hoppus)]
# I got no regret right now (I'm feelin' this!)
# The air is so cold and null (I'm feelin' this!)
# Let me go in her room (I'm feelin' this!)
# I wanna take off her clothes (I'm feelin' this!)
# Show me the way to bed (I'm feelin' this!)
# Show me the way you move (I'm feelin' this!)
# Fuck it, it's such a blur (I'm feelin' this!)
# I love all the things you do (I'm feelin' this!)
# [Chorus: Mark Hoppus]
# Fate fell short this time
# Your smile fades in the summer
# Place your hand in mine
# I'll leave when I wanna
#
# [Verse 2: Tom DeLonge & (Mark Hoppus)]
# Where do we go from here?
# Turn all the lights down now
# Smiling from ear to ear (I'm feelin' this!)
# Our breathing's got too loud (I'm feelin' this!)
# Show me the bedroom floor (I'm feelin' this!)
# Show me the bathroom mirror (I'm feelin' this!)
# We're taking this way too slow (I'm feelin' this!)
# ...

# %% [markdown]
# ## Sunny Day Real Estate

# %%
artist6 = genius.search_artists("Sunny Day Real Estate")
print(artist6['sections'][0]['hits'][0]['result']['id'])
# Out:
# 25325

# %%
sunnyday = genius.search_artist("Sunny Day Real Estate", artist_id = 25325)
for song in sunnyday.songs:
    print(song.lyrics)
# Out:
# Song 1: "In Circles"
# Song 2: "Seven"
# Song 3: "Song About an Angel"
# Song 4: "Pillars"
# Song 5: "48"
# Song 6: "Every Shining Time You Arrive"
# Song 7: "47"
# Song 8: "The Blankets Were The Stairs"
# Song 9: "Grendel"
# Song 10: "Round"
# Song 11: "How It Feels to Be Something On"
# Song 12: "Killed By An Angel"
# Song 13: "8"
# Song 14: "Pheurton Skeurto"
# Song 15: "Sometimes"
# Song 16: "Shadows"
# Song 17: "Guitar and Video Games"
# Song 18: "The Days Were Golden"
# Song 19: "Faces In Disguise"
# Song 20: "9"
# Song 21: "Friday"
# Song 22: "Rain Song"
# Song 23: "The Shark’s Own Private Fuck"
# Song 24: "Red Elephant"
# Song 25: "Roses in Water"
# Song 26: "100 Million"
# Song 27: "One"
# Song 28: "Two Promises"
# Song 29: "Tearing In My Heart"
# Song 30: "Theo B"
# Song 31: "J’Nuh"
# Song 32: "5/4"
# Song 33: "Waffle"
# Song 34: "Rodeo Jones"
# Song 35: "Iscarabaid"
# Song 36: "Snibe"
# Song 37: "The Prophet"
# Song 38: "The Ocean"
# Song 39: "Rising Tide"
# ...

# %%
str(sunnyday.name)
# Out:
# 'Sunny Day Real Estate'

# %% [markdown]
# ## Gerard Way

# %%
artist7 = genius.search_artists("Gerard Way")
print(artist7['sections'][0]['hits'][0]['result']['id'])
# Out:
# 24398

# %%
artist7
# Out:
# {'sections': [{'type': 'artist',
#    'hits': [{'highlights': [],
#      'index': 'artist',
#      'type': 'artist',
#      'result': {'_type': 'artist',
#       'api_path': '/artists/24398',
#       'header_image_url': 'https://images.genius.com/c843f5b9285d09dade87c3488314fad8.1000x447x1.jpg',
#       'id': 24398,
#       'image_url': 'https://images.genius.com/f809ca1c99e79b20e1cc8f1be3fda8d1.401x401x1.jpg',
#       'index_character': 'g',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Gerard Way',
#       'slug': 'Gerard-way',
#       'url': 'https://genius.com/artists/Gerard-way'}},
#     {'highlights': [],
#      'index': 'artist',
#      'type': 'artist',
#      'result': {'_type': 'artist',
#       'api_path': '/artists/1267884',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1666280907',
#       'id': 1267884,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1666280907',
# ...

# %%
#gerard request throwing timeout error, increase timeout from default of 5
genius.timeout = 10
genius.timeout
# Out:
# 10

# %%
gerard = genius.search_artist(artist_name = "Gerard Way")
# Out:
# Searching for songs by Gerard Way...
#
# Song 1: "Brother"
# Song 2: "Baby You’re a Haunted House"
# Song 3: "No Shows"
# Song 4: "Millions"
# Song 5: "Drugstore Perfume"
# Song 6: "Action Cat"
# Song 7: "Dasher"
# Song 8: "Maya The Psychic"
# Song 9: "Don’t Try"
# Song 10: "How It’s Going To Be"
# Song 11: "Juarez"
# "Three Cheers For Sweet Revenge [Tracklist + Album Art]" is not valid. Skipping.
# Song 12: "Happy Together"
# Song 13: "Hazy Shade of Winter"
# Song 14: "Zero Zero"
# Song 15: "The Bureau"
# Song 16: "Get The Gang Together"
# Song 17: "Into The Cave We Wander"
# Song 18: "Pinkish"
# Song 19: "Here Comes the End"
# Song 20: "Television All The Time"
# Song 21: "Getting Down The Germs"
# Song 22: "Piano Jam (Ambulance)"
# Song 23: "Phoning It In"
# Song 24: "Kid Nothing (Unreleased Track)"
# Song 25: "Pogi’s Cavern"
# Song 26: "Frog Dad"
# "The Black Parade Tour Setlist" is not valid. Skipping.
# Song 27: "Superstar"
# "Still Alive" is not valid. Skipping.
# ...

# %%
for song in gerard.songs:
    print(song.lyrics)
# Out:
# Brother Lyrics[Intro]
#
# [Verse 1]
# Does anyone have the time to bring me down?
# And can I sleep all night long
# To the drums of the city rain?
# Just make it up
# 'Cause I'm awake all night long
# To the drums of the city rain
# And brother, if you have the chance to pick me up
# And can I sleep on your couch
# To the pound of the ache and pain?
# Oh, in my head
# 'Cause I'm awake all night long
# To the drums of the city rain
# [Chorus]
# The lights we chase
# The nights we steal
# The things that we take to make us feel this
# (To the drums of the city rain)
# I can't go back (Oh, in my head)
# I don't think I will
# I won't sleep tonight as long as I still ('Cause I'm awake all night long)
# Hear the drums of the city rain
#
# [Verse 2]
# Does anyone have the guts to shut me up?
# 'Cause I believe that every night
# There's a chance we can walk away
# So hold on tight
# Because I won't wait too long
# In the drums of the beating rain
# 'Cause the nights don't last
# ...

# %% [markdown]
# # Corpus Creation

# %%
def LyricDataframe(artist):
   
    #initialize empty attribute lists
    artist_name = str(artist.name)
    artist_name_list = []
    title = []
    lyrics = []
    
    #append song attributes to lits
    for song in artist.songs:
        artist_name_list.append(artist_name)
        title.append(song.title)
        lyrics.append(song.lyrics)
    
    #format lists to feed into dataframe
    key_list = ['Artist', 'Song Title', 'Lyrics']
    value_list = [artist_name_list, title, lyrics]
    
    #create dataframe for artist
    df = pd.DataFrame(value_list).T.set_axis(key_list, axis=1, inplace=False)
    return df

# %%
#apply function to each band
lifetime_df = LyricDataframe(lifetime)
cure_df = LyricDataframe(cure)
jawbreaker_df = LyricDataframe(jawbreaker)
mcr_df = LyricDataframe(mcr)
blink_df = LyricDataframe(blink)
sunnyday_df = LyricDataframe(sunnyday)
gerard_df = LyricDataframe(gerard)

# %%
#create corpus
corpus_df = pd.concat([lifetime_df, cure_df, jawbreaker_df, mcr_df, blink_df, sunnyday_df, gerard_df]).reset_index().drop(['index'], axis=1)
corpus_df
# Out:
#           Artist               Song Title  \
# 0       Lifetime           Turnpike Gates
# 1       Lifetime  Young, Loud, and Scotty
# 2       Lifetime         25 Cent Giraffes
# 3       Lifetime              Hey Catrine
# 4       Lifetime              Rodeo Clown
# ...          ...                      ...
# 1249  Gerard Way   Morning Pages: 9/30/16
# 1250  Gerard Way  Morning Pages: 10/03/16
# 1251  Gerard Way  Morning Pages: 10/14/16
# 1252  Gerard Way  Morning Pages: 10/04/16
# 1253  Gerard Way   Fireworks for The Dead
#
#                                                  Lyrics
# 0     Turnpike Gates Lyrics[Spoken]\nIn order for yo...
# 1     Young, Loud, and Scotty LyricsIs it silly to t...
# 2     25 Cent Giraffes LyricsIt was too loud to hear...
# 3     Hey Catrine LyricsHey Catrine, I know it's tru...
# 4     Rodeo Clown Lyrics[Verse 1]\nReturn it to you,...
# ...                                                 ...
# 1249  Morning Pages: 9/30/16 LyricsHad a great day o...
# ...

# %%
corpus_df['Lyrics'][900]
# Out:
# "Helena (Live At Launch) LyricsHey, we're My Chemical Romance and this song is called Helena\n\nLong ago, just like the\u2005hearse\u2005you die to\u2005get in again\nWe are so far\u2005from you\nBurning on\nJust like the match you strike\nTo incinerate the\u205flives\nOf\u205feveryone\u205fyou know\n\nAnd what's\u205fthe worst you\u205ftake?\nFrom every heart you break?\nAnd like the blade you stain\nWell I've been holding on tonight\nWhat's the worst that I could say?\nThings are better if I stay\nSo long and goodnight\nSo long and goodnight\n\nCame a time\nWhen every starfall brought you to tears again\nWe are the very hurt you sold\n\nAnd what's the worst you take?\nFrom every heart you break?\nAnd like the blade you stain\nWell I've been holding on tonight\n\nWhat's the worst that I could say?\nThings are better if I stay\nSo long and goodnight\nSo long and goodnight\n\nAnd if you carry on this way\nThings are better if I stay\nSo long and goodnight\nSo long and goodnight\n\nCan
# ...

# %%
corpus_df.to_csv('lyric_corpus.csv', index=True)
